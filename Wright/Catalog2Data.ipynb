# %%
myfile = open('Add. 12155.txt', encoding = "utf8") #the txt is still partial.

# %%
#catalog = myfile.read()
florence_txt = myfile.read()

# %%
import pandas as pd
import re

# %%
florence_txt
# Out:
# 'CATENAE PATRUM, ETC.\n921\nof Kephar-Yambu: . ـ•ـ’ـ© ـںـ¬ـ’ـگ ـ—ـ¢ـگ\n[Add. 14,529.]\nDCCCLVIL\nVellum, about 11| in. by 73, consisting of 268 leaves, some of which, especially near the beginning and end, arc much stained and torn. The quires, 27 in number, are signed with letters. With the exception of foll. 1 and 267, each page is divided into two columns, of from 43 to 61 lines. This manuscript is written in a small, neat hand, apparently of the viiith cent. (see below). The writing on foll. 1 and 267 is of somewhat later date, and the same hand has added a few of the marginal notes.\nThe title of the manuscript, fol. 2 b, is:\n. ـ¦ـ¢ـ©ـ\u200cـ¬ـگ ـ•ـ¬ـڑـکـ\u200cـ¬ـگ ـ•ـگـ’ـ—ـ¬ـگ ـ©ـ•ـ\u200cـ«ـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـ—ـھـ£ـ\u200cـ£ ـ،ـ«ـڑ[ـ\xa0ـ¦ـ¬ـگ] , â€œ a volume of Demonstrations from the holy Fathers against various heresies.â€\u200c It is a mono-physite compilation, and the contents arc, as may be supposed, very various.\nI. A collection of Demonstrations, which arc called in
# ...

# %%
 #ms_pattern = re.compile("DCCCLVII.+?12,155", re.S|re.M|re.DOTALL)

# %%
#florence = re.search(ms_pattern, catalog)

# %%
#florence.group()

# %%
#florence_txt= florence.group()

# %%
florence_txt
# Out:
# 'CATENAE PATRUM, ETC.\n921\nof Kephar-Yambu: . ـ•ـ’ـ© ـںـ¬ـ’ـگ ـ—ـ¢ـگ\n[Add. 14,529.]\nDCCCLVIL\nVellum, about 11| in. by 73, consisting of 268 leaves, some of which, especially near the beginning and end, arc much stained and torn. The quires, 27 in number, are signed with letters. With the exception of foll. 1 and 267, each page is divided into two columns, of from 43 to 61 lines. This manuscript is written in a small, neat hand, apparently of the viiith cent. (see below). The writing on foll. 1 and 267 is of somewhat later date, and the same hand has added a few of the marginal notes.\nThe title of the manuscript, fol. 2 b, is:\n. ـ¦ـ¢ـ©ـ\u200cـ¬ـگ ـ•ـ¬ـڑـکـ\u200cـ¬ـگ ـ•ـگـ’ـ—ـ¬ـگ ـ©ـ•ـ\u200cـ«ـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـ—ـھـ£ـ\u200cـ£ ـ،ـ«ـڑ[ـ\xa0ـ¦ـ¬ـگ] , â€œ a volume of Demonstrations from the holy Fathers against various heresies.â€\u200c It is a mono-physite compilation, and the contents arc, as may be supposed, very various.\nI. A collection of Demonstrations, which arc called in
# ...

# %%
section_pattern = re.compile(r'\n[IVXL]{1,7}\..*?(?=(\n[IVXL]{1,7}\.)|\Z)', re.S|re.M|re.MULTILINE|re.DOTALL)

# %%
sections = []
sections
# Out:
# []

# %%
for match in re.finditer(section_pattern, florence_txt):
    sections.append(match.group())

# %%
len(sections)
# Out:
# 2

# %%
sections[0]
# Out:
# '\nI. A collection of Demonstrations, which arc called in the subscription, fol. 32 b,\nـ©ـ¦ـ\xa0ـگـگ ـ•ـ،ـ،ـ\xa0ـ\xa0ـگ ـگـ\xa0ـ—ـ\u200cـگ ـگـک ـںـ\u200cـ¬ ـ•ـ¬ـگـکـ\xa0ـ“ـ\u200cـگ ـگـ\xa0ـ—ـ\u200cـ¬ـگ , â€œ chapters on Theology.â€\u200c They are 108 in number. The authorities cited areâ€”\n1.\tAlexander of Alexandria: fol
ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ¬ـھـ¬ـ\u200cـ¢ ـ•ـ،ـ›ـ\xa0 ـھـکـڑـگ ـ©ـ•ـ\u200cـ«ـگ , as cited by Severus, fol. 25 b.'

# %%
section_1 = first_section_items[1].rsplit(":")
author=section_1[0]
works=section_1[1]
print("the name of the author is: "+ author +", and his texts are: \n" +works)
# Out:
# the name of the author is:
# 2.	Athanasius, and his texts are:
#  ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ ـکـ©ـ’ـ  ـ—ـھـ£ـ‌ـ£ , fol. 2 b; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ©ـ•ـ،ـ‌ـگ ـ•ـ ـکـ©ـ’ـ  ـگـھـ‌ـ¢ـک , foll. 12 b, 20 a and b; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـگـھـ’ـ¥ـگ ـ•ـ ـکـ©ـ’ـ  ـگـھـ‌ـ¢ـک , foll.
# 9 b 20 a; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ،ـ›ـ  ـ•ـ¢ـڑـ— ـ¦ـھـکـ©ـ‌ـگ ـ•ـ،ـ«ـ‌ـڑـگ , foll 13 b, 25 b ; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ،ـ›ـ  ـ—ـ‌ـ،ـ¢ـکـ¬ـگ , fol. 27 b; ـ£ـکـ¢ـ•ـ©ـ›ـ‌ـکـ¢ , fol. 26 a, marg.; ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ ـکـ¬ ـگـکـ£ـ‌ـ’ـ‌ـ£ ـکـ ـکـ©ـ¦ـ‌ـھ ـکـگـ£ـ›ـ•ـ‌ـکـ£ ـکـ©ـکـ،ـ›ـ‌ـکـ£ ـکـگـ›ـ ـ‌ـکـ£ ـگـ¦ـ‌ـ£ـ©ـکـ¦ـگ , foll. 20 b, 31 a; ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ¬ـھـ¬ـ‌ـ¢ ـ•ـ،ـ›ـ  ـھـکـڑـگ ـ©ـ•ـ‌ـ«ـگ , as cited by Severus, fol. 25 b.

# %%
work_pattern = re.compile(r'.*?\;|\Z', re.S|re.MULTILINE|re.DOTALL)#need to solve the empty cell
works_list = re.findall(work_pattern, works)
works_list=(works.rsplit(";"))

# %%
print(works_list)
# Out:
# [' ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـ—ـھـ£ـ\u200cـ£ , fol. 2 b', ' ـ،ـ¢ ـ،ـگـ،ـھـگ ـ©ـ•ـ،ـ\u200cـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـگـھـ\u200cـ¢ـک , foll. 12 b, 20 a and b', ' ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـگـھـ’ـ¥ـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـگـھـ\u200cـ¢ـک , foll.\n9 b 20 a', ' ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ،ـ›ـ\xa0 ـ•ـ¢ـڑـ— ـ¦ـھـکـ©ـ\u200cـگ ـ•ـ،ـ«ـ\u200cـڑـگ , foll 13 b, 25 b ', ' ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ،ـ›ـ\xa0 ـ—ـ\u200cـ،ـ¢ـکـ¬ـگ , fol. 27 b', ' ـ£ـکـ¢ـ•ـ©ـ›ـ\u200cـکـ¢ , fol. 26 a, marg.', ' ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ\xa0ـکـ¬ ـگـکـ£ـ\u200cـ’ـ\u200cـ£ ـکـ\xa0ـکـ©ـ¦ـ\u200cـھ ـکـگـ£ـ›ـ•ـ\u200cـکـ£ ـکـ©ـکـ،ـ›ـ\u200cـکـ£ ـکـگـ›ـ\xa0ـ\u200cـکـ£ ـگـ¦ـ\u200cـ£ـ©ـکـ¦ـگ , foll. 20 b, 31 a', ' ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ¬ـھـ¬ـ\u200cـ¢ ـ•ـ،ـ›ـ\xa0 ـھـکـڑـگ ـ©ـ•ـ\u200cـ«ـگ , as cited by Severus, fol. 25 b.']

# %%
folios_pattern = re.compile(r'(fol.+)([ 0-9abdn,]*)', re.S|re.MULTILINE|re.DOTALL)#add in prefix "f" as beginning of word
folios_match = re.search(folios_pattern, works_list[7])
#folios = folios_match.group()
folios_match.group(1)
# Out:
# 'fol. 25 b.'

# %%
title_pattern = re.compile(r'([fols\.\s\d\z\,ab]*?)', re.S|re.MULTILINE|re.DOTALL)#need to implement author

# %%
second_item_works =[]
for match in re.finditer(item_pattern, first_section_items[1]):
    second_item_works.append(match.group())

# %%
second_item_works[0]
# Out:
# '\n2.\tAthanasius: ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـ—ـھـ£ـ\u200cـ£ , fol. 2 b; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ©ـ•ـ،ـ\u200cـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـگـھـ\u200cـ¢ـک , foll. 12 b, 20 a and b; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـگـھـ’ـ¥ـگ ـ•ـ\xa0ـکـ©ـ’ـ\xa0 ـگـھـ\u200cـ¢ـک , foll.\n9 b 20 a; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ،ـ›ـ\xa0 ـ•ـ¢ـڑـ— ـ¦ـھـکـ©ـ\u200cـگ ـ•ـ،ـ«ـ\u200cـڑـگ , foll 13 b, 25 b ; ـ،ـ¢ ـ،ـگـ،ـھـگ ـ•ـ،ـ›ـ\xa0 ـ—ـ\u200cـ،ـ¢ـکـ¬ـگ , fol. 27 b; ـ£ـکـ¢ـ•ـ©ـ›ـ\u200cـکـ¢ , fol. 26 a, marg.; ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ\xa0ـکـ¬ ـگـکـ£ـ\u200cـ’ـ\u200cـ£ ـکـ\xa0ـکـ©ـ¦ـ\u200cـھ ـکـگـ£ـ›ـ•ـ\u200cـکـ£ ـکـ©ـکـ،ـ›ـ\u200cـکـ£ ـکـگـ›ـ\xa0ـ\u200cـکـ£ ـگـ¦ـ\u200cـ£ـ©ـکـ¦ـگ , foll. 20 b, 31 a; ـ،ـ¢ ـگـ“ـھـ¬ـگ ـ•ـ¬ـھـ¬ـ\u200cـ¢ ـ•ـ،ـ›ـ\xa0 ـھـکـڑـگ ـ©ـ•ـ\u200cـ«ـگ , as cited by Severus, fol. 25 b.'

# %%
#patterns to apply to items (authors) in order to extract their info
folios_pattern = re.compile(r'f\w+l\b\..*?(?=\;|\Z)', re.S|re.MULTILINE|re.DOTALL)
author_pattern = re.compile(r'\d?\..*?(?=\:)', re.S|re.MULTILINE|re.DOTALL)
#title_pattern = ?? 
title_pattern = re.compile(
    r'(\d?\..*?(?=\:))(?<=\:)|(?<=\;)|(?<=[ab]\s\,)|(?<=[ab]\,)(\S*?)(?=(\,.*?f\w+l\b\.)|\;|\Z)', re.S|re.MULTILINE|re.DOTALL|re.VERBOSE)
            #think of slicing the string of the item, each time one out of three details (author-just once, title - could be several titles per author, folios - could be several folios per title)
#item_pattern = re.compile(r'\n\d+\..*?(?=(\n\d+\.)|\Z)', re.S|re.MULTILINE|re.DOTALL)
folios_match= re.findall(title_pattern, first_section_items[1])
folios_match
# Out:
# [('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', '')]

# %%
#first_item_folios =[]
#for match in re.finditer(folio_pattern, first_section_items[2]):
#    first_item_folios.append(match.group())
    
for i in first_section_items[i]:
    author = author_pattern #create data structure (array, etc.) for authors
        #loop over the item and extract for each title\folio:
        #    title = title_pattern
        #   folio = folio_pattern

# %%
len(first_item_folios)
# Out:
# 11

# %%
first_item_folios   #0=a; 6,J,&,fi,ft,i,A=b
                    #pages: B=3,Q=6, 1=7,
# Out:
# ['foil. 2 b, \nB a, Q b,1 b,8 b,9 a, 10 a, 15 a, 16 a and b, \n17 a and b, 18 b, 20 a, 24 b, 25 o',
#  'foil. 6 6, 27 a ',
#  'fol. 13 a',
#  'foil. 16 J, 20 a ',
#  'foil. 16 b ',
#  'foil. 25 a and 6, \n27 a, 28 a ',
#  'foil. 6 &, 23 fi',
#  'foil. 17 b, \n24 ft, 26 a, 27 a',
#  'foil. 9 i, 14 a, 17 J, 24 b, 25 A, \n26 6, 28 J, 30 i ',
#  'fol. 26 a ',
#  'foil. 26 a, 27 a, 30 &, 31 b, \n']

# %%
myfile.close()
